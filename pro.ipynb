# %% [markdown]
# ### AI Job Market

# %% [markdown]
# #### Logistic Regression
#
# >its a classification algorithm
#
# >its formula is based on sigmoid function
#
# ><img src="https://miro.medium.com/v2/resize:fit:1200/1*2IAHsCEZaZtZ9ybziYPDEQ.jpeg">

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
columns1=['job_id','company_name','industry','job_title','skills_required','experience_level','employment_type','location','salary_range_usd','posted_date','company_size','tools_preferred']

# %%
# Load dataset
df=pd.read_csv(r"C:\Users\klegd\Desktop\CC(ML) III Sem\ai_job_market.csv")

# %%
df.columns
# Out:
# Index(['job_id', 'company_name', 'industry', 'job_title', 'skills_required',
#        'experience_level', 'employment_type', 'location', 'salary_range_usd',
#        'posted_date', 'company_size', 'tools_preferred'],
#       dtype='str')

# %%
df
# Out:
#       job_id  ...                  tools_preferred
# 0          1  ...                  KDB+, LangChain
# 1          2  ...        FastAPI, KDB+, TensorFlow
# 2          3  ...  BigQuery, PyTorch, Scikit-learn
# 3          4  ...     TensorFlow, BigQuery, MLflow
# 4          5  ...               PyTorch, LangChain
# ...      ...  ...                              ...
# 1995    1996  ...                           MLflow
# 1996    1997  ...          KDB+, LangChain, MLflow
# 1997    1998  ...                          PyTorch
# 1998    1999  ...      MLflow, TensorFlow, FastAPI
# 1999    2000  ...                           MLflow
#
# [2000 rows x 12 columns]

# %% [markdown]
# ### Standardisation

# %%
from sklearn.preprocessing import StandardScaler


# Check numerical columns
print(df.select_dtypes(include=['int64', 'float64']).columns)

# Select numerical columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Create scaler
scaler = StandardScaler()

# Standardize numerical columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# Check result
print(df.head())
# Out:
# Index(['job_id'], dtype='str')
#      job_id  ...                  tools_preferred
# 0 -1.731185  ...                  KDB+, LangChain
# 1 -1.729453  ...        FastAPI, KDB+, TensorFlow
# 2 -1.727721  ...  BigQuery, PyTorch, Scikit-learn
# 3 -1.725989  ...     TensorFlow, BigQuery, MLflow
# 4 -1.724257  ...               PyTorch, LangChain
#
# [5 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler


# Extract minimum and maximum salary
df["salary_min"] = (
    df["salary_range_usd"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.split("-")
    .str[0]
    .astype(float)
)

df["salary_max"] = (
    df["salary_range_usd"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.split("-")
    .str[1]
    .astype(float)
)

# Create average salary
df["salary_avg"] = (df["salary_min"] + df["salary_max"]) / 2

# Standardize salary features
scaler = StandardScaler()

df[["salary_min", "salary_max", "salary_avg"]] = scaler.fit_transform(
    df[["salary_min", "salary_max", "salary_avg"]]
)

print(df[["salary_min", "salary_max", "salary_avg"]].head())
# Out:
#    salary_min  salary_max  salary_avg
# 0   -0.078891   -0.985653   -0.627339
# 1   -0.528690   -0.139798   -0.326195
# 2    0.913633    1.594470    1.375135
# 3   -1.395062   -0.646491   -1.027238
# 4    0.104140   -0.366674   -0.172187

# %%
train,valid,test=np.split(df.sample(frac=1),[int(0.6*len(df)),int(0.8*len(df))])

# %%
def scale_dataset(dataframe,oversample=False):
    x=dataframe[dataframe.columns[:-1]].values
    y=dataframe[dataframe.columns[-1]].values

    scaler=StandardScaler()
    x=scaler.fit_transform(x)

    if oversample:
        ros=RandomOverSampler()
        x,y = ros.fit_resample(x,y)
    data=np.hstack((x,np.reshape(y,(-1,1))))

    return data, x,y

# %%
# create x and y from the dataframe
# keep only numeric features for scaling and prediction
numeric_df = df.select_dtypes(include=[np.number]).copy()

# last numeric column is used as target; others are predictors
data, x, y = scale_dataset(numeric_df, oversample=False)

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
train = pd.DataFrame(train)
valid = pd.DataFrame(valid)
test = pd.DataFrame(test)

# %%
#### using logistic 
from sklearn.linear_model import LogisticRegression
lrc = LogisticRegression
lrc = LogisticRegression(max_iter=1000)

# %%
# Classification example
y_train = y_train.astype(int)   # or map to class labels
lrc.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
predict=lrc.predict(x_test)

# %%
### model evaluation 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
predict =lrc.predict(x_test)


model = LogisticRegression(max_iter=1000)
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
pred = model.predict(x_test)

print("MSE:", mean_squared_error(y_test, pred)*100)
print("R2:", r2_score(y_test, pred)*100)
# Out:
# MSE: 21.94023152360194
# R2: 79.49699765851754
